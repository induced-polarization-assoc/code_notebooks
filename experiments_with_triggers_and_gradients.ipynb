# %%
import scipy.signal as signal

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 8191, 8192, endpoint=False)

# %%
square = signal.square(2 * np.pi * 4.00 * t) + np.sin(2 * np.pi * 20.00 * t)

# %%
plt.plot(t, square)
plt.show()

# %%
g_square = np.gradient(square)

# %%
plt.plot(t, g_square)
plt.show()

# %%
laplacian_square = np.gradient(np.gradient(square))

# %%
plt.plot(t, laplacian_square)
plt.xlim(2000, 4000)
plt.show()

# %%
saw = signal.sawtooth(2 * np.pi * 4.00 * t)

# %%
g_saw = np.gradient(saw)

# %%
laplacian_saw = np.gradient(saw_g)

# %%
plt.plot(t, g_saw, laplacian_saw)
plt.show()

# %%
ramp = signal.sawtooth(2 * np.pi * 4.00 * t, 0)

# %%
plt.plot(t, ramp)
plt.show()

# %%
g_ramp = np.gradient(ramp)
laplacian_ramp = np.gradient(g_ramp)

# %%
plt.subplot(2,2,1)
plt.plot(t, g_saw)

plt.subplot(2,2,2)
plt.plot(t, g_ramp)

plt.subplot(2,2,3)
plt.plot(t, saw)

plt.subplot(2,2,4)
plt.plot(t, ramp)
plt.show()

# %%
plt.plot(t, laplacian_saw)
plt.show()

# %%
plt.plot(t, laplacian_ramp)
plt.show()

# %%
plt.plot(t, laplacian_square)
plt.show()
